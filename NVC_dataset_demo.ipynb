# %%
# %matplotlib inline
import sys
import os
sys.path.append('python_lib')
from class_nvc_dataset import NvcDataset

# %%
annotation_path = os.path.join('annotations', 'NVC_v201509_trainval.json')
image_root = 'images'

# Load annotations
dataset = NvcDataset(annotation_path, image_root)

# Load pre-calculated image features (VggNet layer 15 feature, optional)
image_features_path = os.path.join('cache', 'NVC_v201509_image_feat_VGGnet.npy')
dataset.load_image_features(image_features_path)
# Out:
# INFO:NvcDataset:Dataset loaded with 11 novel concepts
# INFO:NvcDataset:Train, val, test set initialized

# %%
# Get and print the concepts in the dataset
concepts = dataset.getter_concepts()
print 'Concepts: %s' % ', '.join(concepts)

# Get the image and annotations of the speficied concepts
# Each annotations are representated by a python dictionary with the following keys:
#   - 'concept': novel concepts for the image
#   - 'image_id': unique id for the image
#   - 'image_name': file name for the image
#   - 'train_val_test_split': 'train' or 'val' or 'test'
#   - 'img_feat_vgg': an OPTIONAL image feature vector (vggnet in this case) for the image
#   - 'sentences': a list, each element of the list is a dictionary:
#     - 'raw': a string which is the raw annotated sentence
#     - 'tokens': tokenized sentence, NOT includes the period at the end
#     - 'sentence_id': unique id for the sentence
#     - 'image_id': unique image id that the sentence belongs
concepts_interested = ['kiss', 't-rex', 'tai-ji']
image_list = dataset.getter_image_data_list(concepts_interested, 'train')
print 'Get %d images' % len(image_list)
# Out:
# Concepts: quidditch, t-rex, samisen, tai-ji, huangmei_opera, kiss, rocket_gun, tempura, waterfall, wedding_dress, windmill
# Get 150 images

# %%
dataset.visualize_image_data(image_list[0])
# Out:
# Descriptions:
#   a couple leans in for a kiss
#   a woman with brown hair leaning towards a man with black hair to kiss
#   a girl with long brown hair and bangs kiss a guy with a faux hawk with a necklace on a bed
#   a man wearing a black shirt and a girl with brown red hair having a kiss
#   an couple kiss while sitting on a bed in a dark room

# %%
dataset.visualize_image_data(image_list[69])
# Out:
# Descriptions:
#   a t-rex head is shown with many people under it
#   a t-rex skeleton with a group of people in the background
#   a close up of t-rex skeleton head in front of bright blue sky and trees
#   a close up side view shot of a t-rex skull fossil outside with trees and visitors
#   a close up of the head of a dark skeleton of a t-rex faces left

# %%
dataset.visualize_image_data(image_list[115])
# Out:
# Descriptions:
#   a man in blue is playing tai-ji in front of a lake
#   a man wearing blue doing tai-ji
#   a man in light blue doing tai-ji in front of lake with mountains
#   a man in a shiny light blue uniform holds his hands out by his sides for tai-ji on the ground in front of water
#   a man in a light blue uniform practices tai-ji in front of a lake with some mountains in the back
